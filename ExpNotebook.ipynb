# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
tata = yf.Ticker('TATASTEEL.NS')

# %%
tata.info
# Out:
# {'zip': '400001',
#  'sector': 'Basic Materials',
#  'fullTimeEmployees': 73962,
# ...

# %%
hist = tata.history(period="max")

# %%
hist.to_csv('')

# %%
hist.tail(5)
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2021-06-07  1130.000000  1150.000000  1125.550049  1128.699951  12218592
# 2021-06-08  1132.699951  1132.699951  1100.050049  1111.099976  10834373
# 2021-06-09  1117.000000  1128.000000  1093.949951  1101.000000  11114338
# 2021-06-10  1109.300049  1125.800049  1102.900024  1114.449951   7776764
# 2021-06-11  1127.800049  1164.599976  1113.099976  1158.349976  17445856
#
#             Dividends  Stock Splits
# Date
# 2021-06-07        0.0           0.0
# 2021-06-08        0.0           0.0
# 2021-06-09        0.0           0.0
# 2021-06-10        0.0           0.0
# 2021-06-11        0.0           0.0

# %%
tata.actions.tail(5)
# Out:
#             Dividends  Stock Splits
# Date
# 2016-07-28   7.621893           0.0
# 2017-07-20   9.527366           0.0
# 2018-07-05  10.000000           0.0
# 2019-07-04  13.000000           0.0
# 2020-08-06  10.000000           0.0

# %%
tata.splits
# Out:
# Date
# 2004-08-11    1.5
# Name: Stock Splits, dtype: float64

# %%
tata.financials
# Out:
#                                              2021-03-31       2020-03-31  \
# Research Development                               None             None
# Effect Of Accounting Charges                       None             None
# Income Before Tax                        138436900000.0    -2317200000.0
# Minority Interest                         32696800000.0    25866000000.0
# Net Income                                74902200000.0    15565400000.0
# Selling General Administrative           199088100000.0   208583700000.0
# Gross Profit                             993540300000.0   777985700000.0
# Ebit                                     212706200000.0    83088200000.0
# Operating Income                         212706200000.0    83088200000.0
# Other Operating Expenses                 489409600000.0   401906500000.0
# Interest Expense                         -76067100000.0   -75334600000.0
# Extraordinary Items                                None             None
# ...

# %%
tata.cashflow
# Out:
#                                              2021-03-31    2020-03-31  \
# Investments                               -3.406880e+10 -8.449500e+09
# Change To Liabilities                      0.000000e+00  0.000000e+00
# Total Cashflows From Investing Activities -9.322880e+10 -1.453035e+11
# Net Borrowings                            -3.066055e+11  7.607310e+10
# Total Cash From Financing Activities      -3.708967e+11 -1.694620e+10
# Change To Operating Activities             1.644563e+11  2.634260e+10
# Issuance Of Stock                          3.238950e+10  4.000000e+05
# Net Income                                 7.490220e+10  1.556540e+10
# Change In Cash                            -2.200260e+10  4.462040e+10
# Repurchase Of Stock                       -1.500000e+10 -1.500000e+10
# Effect Of Exchange Rate                   -1.143900e+09  5.182900e+09
# Total Cash From Operating Activities       4.432668e+11  2.016872e+11
# ...
